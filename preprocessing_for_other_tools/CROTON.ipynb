# %% [markdown]
# First we tried running on Windows using the guide found on their GH
#
# https://github.com/vli31/CROTON
#
# ```bash
# conda env create -f croton.yml
# ```

# %% [markdown]
# We got the following error:
#
#
# ```
# Retrieving notices: done
# Channels:
#  - anaconda
#  - bioconda
#  - r
#  - defaults
#  - conda-forge
# Platform: win-64
# Collecting package metadata (repodata.json): done
# Solving environment: failed
#
# PackagesNotFoundError: The following packages are not available from current channels:
#
#   - c-ares==1.15.0=h1de35cc_1001
#   - grpcio==1.31.0=py37h7580e61_0
#   - h5py==2.10.0=py37h0601b69_1
#   - hdf5==1.10.6=hdbbcd12_0
#   - intel-openmp==2019.4=233
#   - libcxx==10.0.0=1
#   - libedit==3.1.20191231=h1de35cc_1
#   - libffi==3.3=hb1e8313_2
#   - libgfortran==3.0.1=h93005f0_2
#   - libopenblas==0.3.10=h0794777_0
#   - libprotobuf==3.12.4=hab81aa3_0
#   - mkl==2019.4=233
#   - mkl-service==2.3.0=py37hfbe908c_0
#   - ncurses==6.2=h0a44026_1
#   - numpy==1.19.1=py37ha6d8c68_0
#   - numpy-base==1.19.1=py37h68fea81_0
#   - openssl==1.1.1g=h1de35cc_0
#   - protobuf==3.12.4=py37hb1e8313_0
#   - python==3.7.9=h26836e1_0
#   - pyyaml==5.3.1=py37haf1e3a3_1
#   - readline==8.0=h1de35cc_0
#   - scipy==1.5.2=py37hadf427e_0
#   - sqlite==3.33.0=hffcf06c_0
#   - tensorboard==1.14.0=py37h80053f4_0
#   - tensorflow==1.14.0=mkl_py37h085be34_0
#   - tensorflow-base==1.14.0=mkl_py37h5a24fda_0
#   - tk==8.6.10=hb0a8c7a_0
#   - wrapt==1.12.1=py37h1de35cc_1
#   - xz==5.2.5=h1de35cc_0
#   - yaml==0.2.5=haf1e3a3_0
#   - zlib==1.2.11=h1de35cc_3
#
# Current channels:
#
#   - https://conda.anaconda.org/anaconda/win-64
#   - https://conda.anaconda.org/bioconda/win-64
#   - https://conda.anaconda.org/r/win-64
#   - https://repo.anaconda.com/pkgs/main/win-64
#   - https://repo.anaconda.com/pkgs/r/win-64
#   - https://repo.anaconda.com/pkgs/msys2/win-64
#   - https://conda.anaconda.org/conda-forge/win-64
#
# To search for alternate channels that may provide the conda package you're
# looking for, navigate to
#
#     https://anaconda.org
#
# and use the search bar at the top of the page.
# ```

# %% [markdown]
# We additionaly requested a non-web server based way to predict on CROTON from the corresponding author, which in turn didn't comply so far, therefore making the tool unusable in current state.
